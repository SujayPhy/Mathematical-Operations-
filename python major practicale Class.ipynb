# %%
print( " I love Bijni Collage ")
# Out:
#  I love Bijni Collage

# %%
5-3
# Out:
# 2

# %%
x=5        #value of X
y="Sujay" #Declearation of variavble of Y
print(" value of x" ,x) #print the4 value of X
# Out:
#  value of x 5

# %%
x= "sarkar"
print("My name is sujay ", x )
# Out:
# My name is sujay  sarkar

# %%
x=5
y=6.8
z="I Am Sujay"
print(type(y))
print(type(x))
print(type(z))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # PYTHON PROGRAM TO GENERATE VALUE OF π

# %%
#Import from  library
import math
print("The Value of π is", math.pi)
# Out:
# The Value of π is 3.141592653589793

# %% [markdown]
# # Programme to find the volume of sphere

# %%
import math
π = math.pi
R = 50 #Radias of the sphere is 50 cm
V = (4/3) * π * R * R * R  #V=volume of sphere
print("Volume of the given sphere ", V )
# Out:
# Volume of the given sphere  523598.7755982988

# %% [markdown]
# # Programme to find Area of Circle

# %%
import math
π = math.pi
r = 27
A = π*r*r
print (" Area of the given circle is" ,A)
# Out:
#  Area of the given circle is 2290.221044466959

# %% [markdown]
# # Programme to find the Area of a square

# %%
import math
side = float (input("Enter Value of side of the aquare:"))
A = side*side
print(" Area of the square is", A)
# Out:
# Enter Value of side of the aquare:69
#  Area of the square is 4761.0

# %% [markdown]
# # Program to find the Sum and average of a list of numbers

# %%
n=int(input("Enter the number of list: "))
a=[]
for i in range(0,n):
    list=int(input("Enter list: "))
    a.append(list)
    s=sum(a)
    avg=sum(a)/n
print("Sum of the list of numbers is  ", s)
print("Average of elements in the list is ",avg)
# Out:
# Enter the number of list: 5
# Enter list: 2
# Enter list: 3
# Enter list: 4
# Enter list: 5
# Enter list: 6
# Sum of the list of numbers is   20
# Average of elements in the list is  4.0
